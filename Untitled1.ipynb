# %% [markdown]
# <a href="https://colab.research.google.com/github/tarunlogic12/Python-Data-Analytics-Portfolio/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
===============================================================================
RETAIL SALES DATA MANIPULATION & REVENUE ANALYTICS PIPELINE
===============================================================================
Author      : Tarun Das
Program     : Data Analytics with Generative AI Pro
Module      : Libraries: NumPy & Pandas
Dataset     : retail_dataset .csv
===============================================================================
"""

import numpy as np
import pandas as pd

print("=" * 80)
print("🛒 RETAIL ENTERPRISE DATA CLEANING & REVENUE ANALYSIS PIPELINE")
print("=" * 80)

# -----------------------------------------------------------------------------
# Q1: LOAD DATASET & INSPECT STRUCTURE
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: We check the dataset first to make sure column names and data
# types are correct. This prevents unexpected errors when processing millions of rows later.
print("\n" + "-" * 60)
print("📊 Q1: LOAD DATASET & CHECK STRUCTURE")
print("-" * 60)

df = pd.read_csv("/content/retail_dataset .csv")

print("✓ Preview of First 5 Rows:")
print(df.head().to_string())

print("\n✓ Dataset Columns & Data Types:")
df.info()


# -----------------------------------------------------------------------------
# Q2: IDENTIFY MISSING VALUES
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: Missing data creates big mistakes in monthly financial reports.
# Finding empty cells early helps us fix bad or incomplete records.
print("\n" + "-" * 60)
print("🔍 Q2: MISSING VALUE AUDIT")
print("-" * 60)

missing_per_column = df.isnull().sum()
total_missing = missing_per_column.sum()

print("Missing Values per Column:")
print(missing_per_column.to_string())
print(f"\n[AUDIT RESULT]: Found a total of {total_missing} missing values in the dataset.")


# -----------------------------------------------------------------------------
# Q3: IMPUTE MISSING QUANTITY & PRICE WITH MEAN
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: If we delete rows just because Quantity or Price is missing,
# we lose valuable order history. Replacing empty spaces with the average (mean)
# keeps our sales totals smooth and balanced.
print("\n" + "-" * 60)
print("🩹 Q3: FILL MISSING QUANTITY & PRICE WITH MEAN")
print("-" * 60)

mean_quantity = df["Quantity"].mean()
mean_price = df["Price"].mean()

print(f"[AVERAGE VALUES]: Calculated Mean Quantity = {mean_quantity:.2f} units")
print(f"[AVERAGE VALUES]: Calculated Mean Price    = ₹{mean_price:.2f}")

df["Quantity"] = df["Quantity"].fillna(mean_quantity)
df["Price"] = df["Price"].fillna(mean_price)

print("✓ Filled missing Quantity and Price values using calculated averages.")


# -----------------------------------------------------------------------------
# Q4: REMOVE ROWS WITH MISSING CATEGORY OR REGION
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: We cannot ship a product if we don't know the Region or Category.
# Deleting these specific missing rows keeps our regional tax and shipping reports 100% accurate.
print("\n" + "-" * 60)
print("🧹 Q4: REMOVE ROWS MISSING CATEGORY OR REGION")
print("-" * 60)

initial_rows = len(df)
df_clean = df.dropna(subset=["Product Category", "Region"]).copy().reset_index(drop=True)
cleaned_rows = len(df_clean)

print(f"Total Rows Before Cleaning : {initial_rows}")
print(f"Total Rows After Cleaning  : {cleaned_rows}")
print(f"✓ Removed {initial_rows - cleaned_rows} rows that had missing Region or Category information.")


# -----------------------------------------------------------------------------
# Q5: CREATE REVENUE COLUMN USING NUMPY
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: Normal Python loops are very slow for big datasets. Using NumPy
# vectorization multiplies lists instantly, making website checkout systems super fast.
print("\n" + "-" * 60)
print("💰 Q5: CREATE REVENUE COLUMN (NUMPY VECTORIZATION)")
print("-" * 60)

df_clean["Revenue"] = np.multiply(df_clean["Quantity"].values, df_clean["Price"].values)

print("✓ Created 'Revenue' column using fast NumPy array multiplication.")
print("\nUpdated Dataset Preview (First 5 Rows):")
print(df_clean.head().to_string())


# -----------------------------------------------------------------------------
# Q6: TOTAL REVENUE CALCULATION USING NUMPY
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: Company owners need one main number to see total sales income
# and track business growth.
print("\n" + "-" * 60)
print("🧮 Q6: CALCULATE TOTAL REVENUE (NUMPY)")
print("-" * 60)

total_revenue = np.sum(df_clean["Revenue"].values)
print(f"✓ Total Sales Revenue Generated: ₹{total_revenue:,.2f}")


# -----------------------------------------------------------------------------
# Q7 & Q8: GROUP BY PRODUCT CATEGORY & TOP/BOTTOM CATEGORIES
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: This shows which products make the most money so store managers
# know what items to stock up on and which slow-selling items to put on discount sale.
print("\n" + "-" * 60)
print("📦 Q7 & Q8: REVENUE BY PRODUCT CATEGORY (TOP & BOTTOM 3)")
print("-" * 60)

category_revenue = df_clean.groupby("Product Category")["Revenue"].sum().reset_index()
category_revenue_sorted = category_revenue.sort_values(by="Revenue", ascending=False).reset_index(drop=True)

top_3_categories = category_revenue_sorted.head(3)
bottom_3_categories = category_revenue_sorted.tail(3)

print("Category Sales Ranking:")
print(category_revenue_sorted.to_string(index=False))

print("\n🥇 Top 3 Best-Selling Categories:")
print(top_3_categories.to_string(index=False))

print("\n🔻 Bottom 3 Lowest-Selling Categories:")
print(bottom_3_categories.to_string(index=False))


# -----------------------------------------------------------------------------
# Q9: GROUP BY REGION & HIGHEST/LOWEST REGION
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: Helps companies decide where to open new warehouses and where
# to run bigger advertisement campaigns to increase low sales.
print("\n" + "-" * 60)
print("🗺️ Q9: REGIONAL SALES PERFORMANCE")
print("-" * 60)

region_revenue = df_clean.groupby("Region")["Revenue"].sum().reset_index()
region_revenue_sorted = region_revenue.sort_values(by="Revenue", ascending=False).reset_index(drop=True)

highest_region = region_revenue_sorted.iloc[0]
lowest_region = region_revenue_sorted.iloc[-1]

print("Regional Sales Breakdown:")
print(region_revenue_sorted.to_string(index=False))

print(f"\n🌟 Top Performing Region    : {highest_region['Region']} (₹{highest_region['Revenue']:,.2f})")
print(f"📉 Lowest Performing Region : {lowest_region['Region']} (₹{lowest_region['Revenue']:,.2f})")


# -----------------------------------------------------------------------------
# Q10: MONTHLY REVENUE & NUMPY STATISTICAL ANALYSIS
# -----------------------------------------------------------------------------
# [REAL-WORLD WHY]: Tracking sales month-by-month helps plan for festive buying seasons.
# Calculating Mean vs Median tells us if high-priced luxury items are changing our average numbers.
print("\n" + "-" * 60)
print("📅 Q10: MONTHLY TRENDS & NUMPY STATISTICS")
print("-" * 60)

df_clean["Date"] = pd.to_datetime(df_clean["Date"], format="%d-%m-%Y")
df_clean["Month"] = df_clean["Date"].dt.to_period("M")

monthly_revenue = df_clean.groupby("Month")["Revenue"].sum().reset_index()
print("Monthly Revenue Summary:")
print(monthly_revenue.to_string(index=False))

revenue_array = df_clean["Revenue"].values
rev_mean = np.mean(revenue_array)
rev_median = np.median(revenue_array)
rev_std = np.std(revenue_array)

print("\n📊 Overall Revenue Statistics (NumPy):")
print(f"✓ Average Order Revenue (Mean)   : ₹{rev_mean:,.2f}")
print(f"✓ Middle Order Revenue (Median)  : ₹{rev_median:,.2f}")
print(f"✓ Sales Variation (Std Dev)      : ₹{rev_std:,.2f}")

print("\n[SIMPLE INSIGHT]: The Mean (₹4,900) is higher than Median (₹3,282). This means")
print("expensive orders (like Furniture) are pulling up the overall average order value.")


# -----------------------------------------------------------------------------
# 💡 EXECUTIVE SUMMARY (BUSINESS LESSON)
# -----------------------------------------------------------------------------
print("\n" + "=" * 80)
print("💡 EXECUTIVE SUMMARY FOR MANAGERS")
print("=" * 80)

print(f"""
1. BEST SELLERS: Furniture and Electronics generate almost 50% of all sales.
   -> Strategy: Always keep enough stock for Furniture in main warehouses.

2. WEAK REGION: North region sells ₹1.53 Lakhs while West region sells only ₹81 Thousands.
   -> Strategy: Spend more marketing budget in the West region to boost sales.

3. ORDER VALUE: High variation (₹4,721) means order amounts jump up and down.
   -> Strategy: Offer combo deals (like Groceries + Household items) to increase smaller order totals.
""")

print("=" * 80)
print("✅ PIPELINE EXECUTION COMPLETE | 0 ERRORS")
print("=" * 80)
# Out:
# ================================================================================
# 🛒 RETAIL ENTERPRISE DATA CLEANING & REVENUE ANALYSIS PIPELINE
# ================================================================================
#
# ------------------------------------------------------------
# 📊 Q1: LOAD DATASET & CHECK STRUCTURE
# ------------------------------------------------------------
# ✓ Preview of First 5 Rows:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date Region
# 0           T001        C015            Books       7.0   167.0  02-02-2023  North
# 1           T002        C004             Toys       4.0   374.0  17-02-2023  South
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024  South
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024  South
# 4           T005        C022            Books       7.0   282.0  27-07-2024   West
#
# ✓ Dataset Columns & Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    100 non-null    object
#  1   Customer ID       100 non-null    object
#  2   Product Category  97 non-null     object
#  3   Quantity          98 non-null     float64
#  4   Price             95 non-null     float64
#  5   Date              100 non-null    object
#  6   Region            98 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 5.6+ KB
#
# ------------------------------------------------------------
# 🔍 Q2: MISSING VALUE AUDIT
# ------------------------------------------------------------
# Missing Values per Column:
# Transaction ID      0
# Customer ID         0
# Product Category    3
# Quantity            2
# Price               5
# Date                0
# Region              2
#
# [AUDIT RESULT]: Found a total of 12 missing values in the dataset.
#
# ------------------------------------------------------------
# 🩹 Q3: FILL MISSING QUANTITY & PRICE WITH MEAN
# ------------------------------------------------------------
# [AVERAGE VALUES]: Calculated Mean Quantity = 5.96 units
# [AVERAGE VALUES]: Calculated Mean Price    = ₹820.53
# ✓ Filled missing Quantity and Price values using calculated averages.
#
# ------------------------------------------------------------
# 🧹 Q4: REMOVE ROWS MISSING CATEGORY OR REGION
# ------------------------------------------------------------
# Total Rows Before Cleaning : 100
# Total Rows After Cleaning  : 95
# ✓ Removed 5 rows that had missing Region or Category information.
#
# ------------------------------------------------------------
# 💰 Q5: CREATE REVENUE COLUMN (NUMPY VECTORIZATION)
# ------------------------------------------------------------
# ✓ Created 'Revenue' column using fast NumPy array multiplication.
#
# Updated Dataset Preview (First 5 Rows):
#   Transaction ID Customer ID Product Category  Quantity   Price        Date Region  Revenue
# 0           T001        C015            Books       7.0   167.0  02-02-2023  North   1169.0
# 1           T002        C004             Toys       4.0   374.0  17-02-2023  South   1496.0
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024  South   8472.0
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024  South   1520.0
# 4           T005        C022            Books       7.0   282.0  27-07-2024   West   1974.0
#
# ------------------------------------------------------------
# 🧮 Q6: CALCULATE TOTAL REVENUE (NUMPY)
# ------------------------------------------------------------
# ✓ Total Sales Revenue Generated: ₹465,529.66
#
# ------------------------------------------------------------
# 📦 Q7 & Q8: REVENUE BY PRODUCT CATEGORY (TOP & BOTTOM 3)
# ------------------------------------------------------------
# Category Sales Ranking:
# Product Category       Revenue
#        Furniture 129664.526316
#      Electronics  93204.315789
#         Clothing  85006.000000
#             Toys  53947.879699
#           Sports  34484.000000
#            Books  29597.938776
#           Beauty  27647.000000
#        Groceries  11978.000000
#
# 🥇 Top 3 Best-Selling Categories:
# Product Category       Revenue
#        Furniture 129664.526316
#      Electronics  93204.315789
#         Clothing  85006.000000
#
# 🔻 Bottom 3 Lowest-Selling Categories:
# Product Category      Revenue
#            Books 29597.938776
#           Beauty 27647.000000
#        Groceries 11978.000000
#
# ------------------------------------------------------------
# 🗺️ Q9: REGIONAL SALES PERFORMANCE
# ------------------------------------------------------------
# Regional Sales Breakdown:
# Region       Revenue
#  North 153244.353383
#   East 126232.044039
#  South 104855.736842
#   West  81197.526316
#
# 🌟 Top Performing Region    : North (₹153,244.35)
# 📉 Lowest Performing Region : West (₹81,197.53)
#
# ------------------------------------------------------------
# 📅 Q10: MONTHLY TRENDS & NUMPY STATISTICS
# ------------------------------------------------------------
# Monthly Revenue Summary:
#   Month      Revenue
# 2023-01 24226.000000
# 2023-02  5017.000000
# 2023-03  4184.000000
# 2023-04 37089.526316
# 2023-06  1089.000000
# 2023-07 14532.210526
# 2023-08 67718.000000
# 2023-09  8511.000000
# 2023-10 11448.000000
# 2023-11  6492.000000
# 2023-12  1609.000000
# 2024-01 19768.000000
# 2024-02 28011.000000
# 2024-03  6373.000000
# 2024-04 20209.000000
# 2024-05 27915.000000
# 2024-06 27101.000000
# 2024-07 33319.081633
# 2024-08  9240.000000
# 2024-09 22208.105263
# 2024-10 26569.000000
# 2024-11 21170.736842
# 2024-12 41730.000000
#
# 📊 Overall Revenue Statistics (NumPy):
# ✓ Average Order Revenue (Mean)   : ₹4,900.31
# ✓ Middle Order Revenue (Median)  : ₹3,282.11
# ✓ Sales Variation (Std Dev)      : ₹4,721.17
#
# [SIMPLE INSIGHT]: The Mean (₹4,900) is higher than Median (₹3,282). This means
# expensive orders (like Furniture) are pulling up the overall average order value.
#
# ================================================================================
# 💡 EXECUTIVE SUMMARY FOR MANAGERS
# ================================================================================
#
# 1. BEST SELLERS: Furniture and Electronics generate almost 50% of all sales.
#    -> Strategy: Always keep enough stock for Furniture in main warehouses.
#
# 2. WEAK REGION: North region sells ₹1.53 Lakhs while West region sells only ₹81 Thousands.
#    -> Strategy: Spend more marketing budget in the West region to boost sales.
#
# 3. ORDER VALUE: High variation (₹4,721) means order amounts jump up and down.
#    -> Strategy: Offer combo deals (like Groceries + Household items) to increase smaller order totals.
#
# ================================================================================
# ✅ PIPELINE EXECUTION COMPLETE | 0 ERRORS
# ================================================================================

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'Month' to string for better plotting on x-axis
monthly_revenue['Month_str'] = monthly_revenue['Month'].astype(str)

fig = plt.figure(figsize=(15, 7))
sns.barplot(x='Month_str', y='Revenue', data=monthly_revenue, hue='Month_str', palette='viridis', legend=False)
plt.title('Monthly Revenue Trends')
plt.xlabel('Month')
plt.ylabel('Total Revenue (₹)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Set up Git in Google Colab
#
# First, you need to configure your Git user name and email within the Colab environment. This ensures your commits are correctly attributed to you. Replace `"Your Name"` and `"your_email@example.com"` with your actual GitHub name and email.

# %%
# !git config --global user.name "Your Name"
# !git config --global user.email "your_email@example.com"

# Verify the configuration
# !git config --list
# Out:
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# user.name=Your Name
# user.email=your_email@example.com

# %% [markdown]
# ### Clone your GitHub Repository
#
# Next, you'll clone your GitHub repository. This will pull down all the files from your repository into your Colab environment. Make sure to use the HTTPS URL of your repository (e.g., `https://github.com/your-username/your-repo-name.git`).
#
# **Important:** If your repository is private or you are pushing updates, you'll need to use a GitHub Personal Access Token (PAT) for authentication. Create a PAT in your GitHub settings (`Settings` > `Developer settings` > `Personal access tokens`) with appropriate `repo` permissions. Store it securely in Colab secrets as `GITHUB_TOKEN`.

# %%
# IMPORTANT: Replace 'Tarunlogic12' and 'Python-Data-Analytics-Portfolio' with your actual GitHub details.
# Example: !git clone https://github.com/octocat/Spoon-Knife.git

# For private repos or pushing, use a PAT stored in Colab secrets:
# from google.colab import userdata
# GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
# !git clone https://{GITHUB_TOKEN}@github.com/your-username/your-repo-name.git

# For public repos or if you've already authenticated (e.g., via browser pop-up),
# you can clone directly:
# !git clone https://github.com/Tarunlogic12/Python-Data-Analytics-Portfolio.git

# Navigate into your repository directory (ONLY after successful cloning)
# %cd Python-Data-Analytics-Portfolio
# Out:
# Cloning into 'Python-Data-Analytics-Portfolio'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 34 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 57.47 KiB | 3.02 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/Python-Data-Analytics-Portfolio

# %%
# Create the new subdirectory within your cloned repository
# !mkdir -p 02_NumPy_Pandas_Retail
print("✓ Created directory: 02_NumPy_Pandas_Retail")

# Verify the directory creation (optional)
# !ls
# Out:
# ✓ Created directory: 02_NumPy_Pandas_Retail
# 01_Python_Core_Logic  02_NumPy_Pandas_Retail  README.md  Untitled1.ipynb

# %% [markdown]
# ### Next Steps to Save and Upload Your Notebook:
#
# 1.  **Save your current Colab notebook into the newly created `02_NumPy_Pandas_Retail` folder.**
#     *   Go to `File` > `Save a copy in Drive` (to ensure your latest work is saved within Colab).
#     *   Then, go to `File` > `Save a copy to GitHub...`. In the pop-up, navigate into your `Python-Data-Analytics-Portfolio` repository, and then select the `02_NumPy_Pandas_Retail` subdirectory as the destination for your notebook. Make sure to give it a descriptive name like `retail_sales_analysis.ipynb`.
#
# 2.  **Commit and Push your changes to GitHub.**
#     *   Once you've saved the notebook into the correct subdirectory, execute cell `b321c14a` below.
#     *   This cell will `git add` all the new files (including your notebook in its new location), `git commit` them with a message, and `git push` them to your GitHub repository.

# %% [markdown]
# ### Save and Commit Your Notebook
#
# Now, you would typically save your `.ipynb` file (from Colab's `File > Save` menu) directly into the cloned repository's directory. For example, if your repository is named `my-analytics-project`, you'd save `retail_sales_analysis.ipynb` inside `my-analytics-project/`.
#
# Once saved, you can add, commit, and push your changes. If you are continuing to work on the notebook in the cloned directory, you would overwrite the existing `.ipynb` file when saving from Colab.
#
# **Example steps to commit and push:**

# %%
# Navigate into your repository directory first
# %cd /content/Python-Data-Analytics-Portfolio

# Check the status of your repository
# !git status

# Add all changes (including your .ipynb file and the new directory)
# !git add .

# Commit your changes with a descriptive message
# !git commit -m "Add/Update retail sales analysis notebook with monthly trends visualization and new subdirectory"

# Push your changes to the remote repository (e.g., 'main' branch)
# If you used a PAT for cloning, you might not need to provide credentials again here.
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# ### Professional Analyst Best Practices for GitHub
#
# To truly act like a 'pro analyst' and make your GitHub repository impactful, consider these additional points, which apply whether you use Colab's direct save or a Git workflow:
#
# *   **Comprehensive `README.md`:** This is crucial. It should clearly explain the business problem addressed, the dataset, methodology, key insights (like your Executive Summary), and actionable recommendations.
# *   **Clear Notebook Structure:** Use Markdown cells effectively for headings, explanations, and `[REAL-WORLD WHY]` sections (which you're already doing well!). This makes your analysis easy to follow.
# *   **Version Control with Meaningful Commits:** Each commit should represent a logical, self-contained change (e.g., "Implement data cleaning steps", "Add monthly revenue visualization").
# *   **Clean Code and Comments:** Ensure your Python code is readable, well-commented, and avoids unnecessary complexity.
# *   **Visualizations:** Include all relevant plots and charts, ensuring they are properly labeled and convey insights clearly.
# *   **Documentation for External Dependencies:** If your project requires specific library versions or data files, mention them in your `README.md`.
#
# By combining these methods, you can manage your work effectively on GitHub and showcase your analytical skills in a professional manner.
